# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла." data-toc-modified-id="Изучение-данных-из-файла.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла.</a></span><ul class="toc-item"><li><span><a href="#Описание-данных-из-документации." data-toc-modified-id="Описание-данных-из-документации.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных из документации.</a></span></li><li><span><a href="#Вывод." data-toc-modified-id="Вывод.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вывод.</a></span></li></ul></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных.</a></span><ul class="toc-item"><li><span><a href="#Переименование-столбцов-df." data-toc-modified-id="Переименование-столбцов-df.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименование столбцов df.</a></span></li><li><span><a href="#Проверка-на-явные-дубликаты" data-toc-modified-id="Проверка-на-явные-дубликаты-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка на явные дубликаты</a></span></li><li><span><a href="#Пропущенные-значения" data-toc-modified-id="Пропущенные-значения-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Пропущенные значения</a></span></li><li><span><a href="#Колонка-locality_name-и-airport_nearest." data-toc-modified-id="Колонка-locality_name-и-airport_nearest.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Колонка locality_name и airport_nearest.</a></span></li><li><span><a href="#Колонка-balcony." data-toc-modified-id="Колонка-balcony.-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Колонка balcony.</a></span></li><li><span><a href="#Колонка-ceiling_height" data-toc-modified-id="Колонка-ceiling_height-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Колонка ceiling_height</a></span></li><li><span><a href="#Колонка-floors_total." data-toc-modified-id="Колонка-floors_total.-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Колонка floors_total.</a></span></li><li><span><a href="#Колонка-city_centers_nearest" data-toc-modified-id="Колонка-city_centers_nearest-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Колонка city_centers_nearest</a></span></li><li><span><a href="#Колонка-is_apartment." data-toc-modified-id="Колонка-is_apartment.-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Колонка is_apartment.</a></span></li><li><span><a href="#Колонка-kitchen_area." data-toc-modified-id="Колонка-kitchen_area.-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Колонка kitchen_area.</a></span></li><li><span><a href="#Колонка-living_area." data-toc-modified-id="Колонка-living_area.-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Колонка living_area.</a></span></li><li><span><a href="#Колонки-parks_around_3_km-и-parks_nearest." data-toc-modified-id="Колонки-parks_around_3_km-и-parks_nearest.-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Колонки parks_around_3_km и parks_nearest.</a></span></li><li><span><a href="#Колонки-ponds_around_3_km-и-ponds_nearest." data-toc-modified-id="Колонки-ponds_around_3_km-и-ponds_nearest.-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Колонки ponds_around_3_km и ponds_nearest.</a></span></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Выводы.</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу." data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу.</a></span><ul class="toc-item"><li><span><a href="#Расчет-цены-квадратного-метра." data-toc-modified-id="Расчет-цены-квадратного-метра.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Расчет цены квадратного метра.</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления." data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления.</a></span></li><li><span><a href="#Категоризация-этажа-квартиры-(первый,-последний,-другой)." data-toc-modified-id="Категоризация-этажа-квартиры-(первый,-последний,-другой).-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Категоризация этажа квартиры (первый, последний, другой).</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади." data-toc-modified-id="Соотношение-жилой-и-общей-площади.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Соотношение жилой и общей площади.</a></span></li><li><span><a href="#Соотношение-площади-кухни-к-общей." data-toc-modified-id="Соотношение-площади-кухни-к-общей.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Соотношение площади кухни к общей.</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных." data-toc-modified-id="Исследовательский-анализ-данных.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных.</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров-квартир." data-toc-modified-id="Изучение-параметров-квартир.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров квартир.</a></span><ul class="toc-item"><li><span><a href="#Площадь." data-toc-modified-id="Площадь.-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь.</a></span></li><li><span><a href="#Цена." data-toc-modified-id="Цена.-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена.</a></span></li><li><span><a href="#Число-комнат." data-toc-modified-id="Число-комнат.-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат.</a></span></li><li><span><a href="#Высота-потолков." data-toc-modified-id="Высота-потолков.-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков.</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры." data-toc-modified-id="Время-продажи-квартиры.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры.</a></span></li><li><span><a href="#Выбивающиеся-значения-и-их-влияние." data-toc-modified-id="Выбивающиеся-значения-и-их-влияние.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выбивающиеся значения и их влияние.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры?</a></span><ul class="toc-item"><li><span><a href="#Зависимость-цены-от-площади." data-toc-modified-id="Зависимость-цены-от-площади.-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Зависимость цены от площади.</a></span></li><li><span><a href="#Зависимость-цены-от-числа-комнат." data-toc-modified-id="Зависимость-цены-от-числа-комнат.-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость цены от числа комнат.</a></span></li><li><span><a href="#Зависимость-цены-от-удаленности-от-центра." data-toc-modified-id="Зависимость-цены-от-удаленности-от-центра.-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость цены от удаленности от центра.</a></span></li><li><span><a href="#Зависимость-цены-от-этажа." data-toc-modified-id="Зависимость-цены-от-этажа.-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Зависимость цены от этажа.</a></span></li><li><span><a href="#Зависимость-цены-от-дня-недели-размещения." data-toc-modified-id="Зависимость-цены-от-дня-недели-размещения.-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Зависимость цены от дня недели размещения.</a></span></li><li><span><a href="#Зависимость-цены-от-месяца-размещения-объявления." data-toc-modified-id="Зависимость-цены-от-месяца-размещения-объявления.-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>Зависимость цены от месяца размещения объявления.</a></span></li><li><span><a href="#Зависимость-цены-от-года-размещения." data-toc-modified-id="Зависимость-цены-от-года-размещения.-4.4.7"><span class="toc-item-num">4.4.7&nbsp;&nbsp;</span>Зависимость цены от года размещения.</a></span></li><li><span><a href="#Определение-зависимости-между-параметрами-цена,-общая-площадь,-количество-комнат-и-расстояние-до-центра." data-toc-modified-id="Определение-зависимости-между-параметрами-цена,-общая-площадь,-количество-комнат-и-расстояние-до-центра.-4.4.8"><span class="toc-item-num">4.4.8&nbsp;&nbsp;</span>Определение зависимости между параметрами цена, общая площадь, количество комнат и расстояние до центра.</a></span></li></ul></li><li><span><a href="#Населенные-пункты-с-наибольшим-числом-объявлений." data-toc-modified-id="Населенные-пункты-с-наибольшим-числом-объявлений.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Населенные пункты с наибольшим числом объявлений.</a></span></li><li><span><a href="#Зависимость-цены-от-удаленности-от-центра-в-Санкт---Петербурге." data-toc-modified-id="Зависимость-цены-от-удаленности-от-центра-в-Санкт---Петербурге.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Зависимость цены от удаленности от центра в Санкт - Петербурге.</a></span></li><li><span><a href="#Параметры-сегмента-квартир-в-центре-Санкт---Петербурга." data-toc-modified-id="Параметры-сегмента-квартир-в-центре-Санкт---Петербурга.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Параметры сегмента квартир в центре Санкт - Петербурга.</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров-квартир-в-центре-Санкт-Петербурга." data-toc-modified-id="Изучение-параметров-квартир-в-центре-Санкт-Петербурга.-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Изучение параметров квартир в центре Санкт-Петербурга.</a></span><ul class="toc-item"><li><span><a href="#Площадь." data-toc-modified-id="Площадь.-4.7.1.1"><span class="toc-item-num">4.7.1.1&nbsp;&nbsp;</span>Площадь.</a></span></li><li><span><a href="#Цена." data-toc-modified-id="Цена.-4.7.1.2"><span class="toc-item-num">4.7.1.2&nbsp;&nbsp;</span>Цена.</a></span></li><li><span><a href="#Число-комнат." data-toc-modified-id="Число-комнат.-4.7.1.3"><span class="toc-item-num">4.7.1.3&nbsp;&nbsp;</span>Число комнат.</a></span></li><li><span><a href="#Высота-потолков." data-toc-modified-id="Высота-потолков.-4.7.1.4"><span class="toc-item-num">4.7.1.4&nbsp;&nbsp;</span>Высота потолков.</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры." data-toc-modified-id="Время-продажи-квартиры.-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Время продажи квартиры.</a></span></li><li><span><a href="#Зависимость-цены-от-площади." data-toc-modified-id="Зависимость-цены-от-площади.-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Зависимость цены от площади.</a></span></li><li><span><a href="#Зависимость-цены-от-числа-комнат." data-toc-modified-id="Зависимость-цены-от-числа-комнат.-4.7.4"><span class="toc-item-num">4.7.4&nbsp;&nbsp;</span>Зависимость цены от числа комнат.</a></span></li><li><span><a href="#Зависимость-цены-от-удаленности-от-центра." data-toc-modified-id="Зависимость-цены-от-удаленности-от-центра.-4.7.5"><span class="toc-item-num">4.7.5&nbsp;&nbsp;</span>Зависимость цены от удаленности от центра.</a></span></li><li><span><a href="#Зависимость-цены-от-этажа." data-toc-modified-id="Зависимость-цены-от-этажа.-4.7.6"><span class="toc-item-num">4.7.6&nbsp;&nbsp;</span>Зависимость цены от этажа.</a></span></li><li><span><a href="#Зависимость-цены-от-дня-недели-размещения." data-toc-modified-id="Зависимость-цены-от-дня-недели-размещения.-4.7.7"><span class="toc-item-num">4.7.7&nbsp;&nbsp;</span>Зависимость цены от дня недели размещения.</a></span></li><li><span><a href="#Зависимость-цены-от-месяца-размещения." data-toc-modified-id="Зависимость-цены-от-месяца-размещения.-4.7.8"><span class="toc-item-num">4.7.8&nbsp;&nbsp;</span>Зависимость цены от месяца размещения.</a></span></li><li><span><a href="#Зависимость-цены-от-года-размещения." data-toc-modified-id="Зависимость-цены-от-года-размещения.-4.7.9"><span class="toc-item-num">4.7.9&nbsp;&nbsp;</span>Зависимость цены от года размещения.</a></span></li><li><span><a href="#Определение-корреляционной-зависимости-между-параметрами-цена,-количество-комнат,-общая-площадь-и-расстояние-до-центра." data-toc-modified-id="Определение-корреляционной-зависимости-между-параметрами-цена,-количество-комнат,-общая-площадь-и-расстояние-до-центра.-4.7.10"><span class="toc-item-num">4.7.10&nbsp;&nbsp;</span>Определение корреляционной зависимости между параметрами цена, количество комнат, общая площадь и расстояние до центра.</a></span></li><li><span><a href="#Выводы-по-исследованию-для-сегмента-центр-Санкт---Петербурга." data-toc-modified-id="Выводы-по-исследованию-для-сегмента-центр-Санкт---Петербурга.-4.7.11"><span class="toc-item-num">4.7.11&nbsp;&nbsp;</span>Выводы по исследованию для сегмента центр Санкт - Петербурга.</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# **Цель исследования** — оценить основные параметры недвижимости и степень их связи с рыночной стоимостью недвижимости.
#
# **Ход исследования**
#
# Данные представлены в файле: `/datasets/real_estate_data.csv`- это архив объявлений о продаже квартир в Санкт-Петербурге и его окрестностях, диапазон архива ограничен несколькими годами.  Часть данных заполнена автоматически, а часть - непосредственно пользователем, что может повлечь за собой существенные ошибки и пропуски в данных. Поэтому перед проверкой гипотез необходимо провести обзор данных и предобработку.
#
# Исследование планируется провести в несколько этапов:
#  1. Обзор данных.
#  2. Предобработка данных.
#  3. Ответы на вопросы по проекту и формирование общего вывода.
#
# Результаты исследования будут использоваться при определении рыночной стоимости недвижимости.

# %% [markdown]
# ## Изучение данных из файла.

# %% [markdown]
# Первым шагом в исследовании необходимо ознакомиться с представленными данными.

# %%
# подключаем нужные нам в исследовании библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
# загрузим датасет
try:
    df = pd.read_csv('C:/Users/1/Downloads/real_estate_data(1).csv', sep = '\t')
except:
    df = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %%
# выгружаем первые 10 строк
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
# выведем последние 10 строк
df.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13   3550000.0       35.30  2018-02-28T00:00:00      1
# 23690             3   5500000.0       52.00  2018-07-19T00:00:00      2
# 23691            11   9470000.0       72.90  2016-10-13T00:00:00      2
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23693             9   4600000.0       62.40  2016-08-05T00:00:00      3
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23689            2.86          15.0         16.3      4          NaN  ...
# ...

# %%
# рассмотрим общую информацию по датасету
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Описание данных из документации.
#
# Описание данных, представленных в проекте:
#
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * cityCenters_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * first_day_exposition — дата публикации
# * floor — этаж
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * last_price — цена на момент снятия с публикации
# * living_area — жилая площадь в квадратных метрах (м²)
# * locality_name — название населённого пункта
# * open_plan — свободная планировка (булев тип)
# * parks_around3000 — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around3000 — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)
# * rooms — число комнат
# * studio — квартира-студия (булев тип)
# * total_area — площадь квартиры в квадратных метрах (м²)
# * total_images — число фотографий квартиры в объявлении

# %% [markdown]
# ### Вывод.

# %% [markdown]
#  В таблице представлены 23699 строк и 22 столбца.
#
# В каждой строке дата-сета представлены данные об одном объекте недвижимости, который располагается в Санкт-Петербурге и его окрестностях.
#
#  В данных представлены 2 столбца с булевыми типами данных, тогда как по документации таких столбцов должно быть три. Также представлены 14 столбцов с типом данных float, 3 - int и еще 3 - object.
#
#  Судя по имеющимся данным о количестве заполненных строк, в части из них имеются пропуски данных.
#
#  Представленная информация обезличена, персональные данные о владельцах квартир отсутствуют.
#
#  Основываясь на представленных данных можно сделать вывод, что данных достаточно для проведения исследования по проекту.
#
#  Названия колонок заполнены некорректно, присутствуют нарушения стиля в следующих столбцах: cityCenters_nearest, parks_around3000, ponds_around3000.

# %% [markdown]
# ## Предобработка данных.

# %% [markdown]
# ### Переименование столбцов df.

# %%
# переименование столбца
df= df.rename( 
 columns={ 
'cityCenters_nearest': 'city_centers_nearest',
   'parks_around3000': 'parks_around_3_km',
   'ponds_around3000': 'ponds_around_3_km',
 }
)

# %% [markdown]
# ###  Проверка на явные дубликаты

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явные дубликаты не выявлены.

# %% [markdown]
# ### Пропущенные значения

# %%
# определим количество пропущенных значений по столбцам
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3_km        5518
# parks_nearest           15620
# ponds_around_3_km        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
# определим процентное соотношение пропусков в df
df.isnull().sum()/df.shape[0]*100
# Out:
# total_images             0.000000
# last_price               0.000000
# total_area               0.000000
# first_day_exposition     0.000000
# rooms                    0.000000
# ceiling_height          38.799105
# floors_total             0.362885
# living_area              8.029875
# floor                    0.000000
# is_apartment            88.290645
# studio                   0.000000
# open_plan                0.000000
# kitchen_area             9.612220
# balcony                 48.605426
# locality_name            0.206760
# airports_nearest        23.384953
# city_centers_nearest    23.287902
# parks_around_3_km       23.283683
# parks_nearest           65.909954
# ponds_around_3_km       23.283683
# ponds_nearest           61.559559
# days_exposition         13.422507
# dtype: float64

# %% [markdown]
# Данные пропущены в следующих столбцах df:
#
# * airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# * balcony — число балконов
# * ceiling_height — высота потолков (м)
# * city_centers_nearest — расстояние до центра города (м)
# * days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# * floors_total — всего этажей в доме
# * is_apartment — апартаменты (булев тип)
# * kitchen_area — площадь кухни в квадратных метрах (м²)
# * living_area — жилая площадь в квадратных метрах (м²)
# * locality_name — название населённого пункта
# * parks_around_3_km — число парков в радиусе 3 км
# * parks_nearest — расстояние до ближайшего парка (м)
# * ponds_around_3_km — число водоёмов в радиусе 3 км
# * ponds_nearest — расстояние до ближайшего водоёма (м)

# %% [markdown]
# **Вывод**
#
# Пропущенные значения столбца airports_nearest - рассмотрим взаимосвязь между данным параметром и locality_name, рассмотрим количество и определение уникальных значений locality_name.
#
# Для колонки balcony будем считать, что по всем пропущенным объектам балконы отсутствуют, заполним значением 0.
#
# Пропущенные значения колонки ceiling_height заполним средним, которое будет рассчитываться как среднее для указанного количества комнат.
#
# Пропущенные значения столбца city_centers_nearest - проверим связь между данным параметром и locality_name, при наличии связи заполним средним значением по locality_name для населенных пунктов. Если связь между значениями не будет обнаружена, оставим значения незаполненными по всем регионам.
#
# По незаполненные значениям в колонке days_exposition предположим, что данное значение рассчитывается системой автоматически (в реальном проекте уточним у ответственного за содержание БД, заказчика и т.д.) и может быть незаполнено в том случае, если объявление так и не было снято с публикации. Оценим влияние данных объявлений на базу в целом (на первом этапе оставим без изменений).
#
# Пропущенные значения floors_total заполним, сопоставив со значением floor в объявлении (заполним данным значением пропуски, т.к. в здании вероятнее всего не может быть меньше этажей, чем этаж продаваемого помещения). Их количество невелико (86 записей), принимаем гипотезу, что сильного влияния на данные не окажет.
#
#
# Значения в is_apartment проверим на тип данных и содержание сведений внутри данных, т.к. судя по количеству пропусков, данный раздел оставался незаполненным при объекте другого типа (не аппартаменты).
#
# Значения колонок kitchen_area и living_area необходимо дополнительно проанализировать в совокупности и проверить - при наличии
# заполненной площади кухни, предположительно общая площадь должна быть известна. Выдвинем гипотезу, что некоторые квартиры (в том числе аппартаменты, необходимо проверить свзяь между незаполненным значением столбца kitchen_area и значением в столбце appartment, rooms, studio) не имеют выделенной кухни, в таком случае, ее площадь может быть записана как 0 м2. В зависимости от значений столбца rooms можно заполнить медианным значением столбец living_area.
#
# Значения строк с незаполненым locality_name (название населенного пункта) удалим, т.к. данные значения составляют небольшую часть данных (49 пропушенных значений), но при этом отсутствует значительная часть сведений (например, такие значения могут быть не из Санкт-Петербурга и его окрестностей, т.к. географическое расположение не указано).
#
# Дополнительно рассмотрим связь между колонками parks_around_3_km и parks_nearest, выдвинем гипотезу, что при отсутствии данных в столбце parks_nearest и наличии положительного значения в столце parks_around_3_km, пропущенное значение столбца parks_nearest будет заполнено медианным для данного населенного пункта. При отсутствии такой взаимосвязи значение оставляем незаполненным.
#
# Дополнительно рассмотрим связь между колонками ponds_around_3_km и ponds_nearest, выдвинем гипотезу, что при отсутствии данных в столбце ponds_nearest и наличии положительного значения в столце ponds_around_3_km, пропущенное значение столбца ponds_nearest будет медианным для данного населенного пункта. При отсутствии такой взаимосвязи значение оставляем незаполненным.

# %% [markdown]
# ### Колонка locality_name и airport_nearest.

# %%
# удалим пропущенные значения столбца locality_name
df = df.dropna(subset=['locality_name'])

# %%
# определим количество уникальных значений столбца locality_name
df['locality_name'].value_counts()
# Out:
# Санкт-Петербург                      15721
# посёлок Мурино                         522
# посёлок Шушары                         440
# Всеволожск                             398
# Пушкин                                 369
#                                      ...
# садовое товарищество Приладожский        1
# поселок Пансионат Зелёный Бор            1
# деревня Лаврики                          1
# село Никольское                          1
# деревня Хапо-Ое                          1
# Name: locality_name, Length: 364, dtype: int64

# %%
# выведем значения уникальных значений столбца и количество уникальных значений
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Рассмотрев список полученных уникальных значений столбца locality_name можно заметить, что встречаются неявные дубликаты, например: поселок Пансионат Зелёный Бор и посёлок Пансионат Зелёный Бор, при сверке со списком объектов Ленинградской области,  являются одним и тем же объектом с разной формой записи. Для исключения подобных дубликатов (с учетом разницы в записи 1 символа), заменим 'ё' на 'е' в названии населённых пунктов.

# %%
# переименуем населённые пункты и устраним букву ё в названиях
df['locality_name'] = df['locality_name'].str.replace('ё', 'е')

# %%
# для устранения дублирующих локаций удалим конкретизацию локаций во всем списке
df['locality_name'] = df['locality_name'].str.replace('поселок ', '')
df['locality_name'] = df['locality_name'].str.replace('поселок городского типа ', 'городской поселок ')
df['locality_name'] = df['locality_name'].str.replace('деревня ', '')
df['locality_name'] = df['locality_name'].str.replace('село ', '')

# %%
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'Шушары', 'городской Янино-1', 'Парголово',
#        'Мурино', 'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин',
#        'Кудрово', 'Коммунар', 'Колпино', 'городского типа Красный Бор',
#        'Гатчина', 'Федоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'Новое Девяткино', 'Металлострой', 'городского типа Лебяжье',
#        'городского типа Сиверский', 'Молодцово',
#        'городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'Куттузи', 'Аннино', 'городского типа Ефимовский', 'Плодовое',
#        'Заклинье', 'Торковичи', 'Первомайское', 'Красное Село',
#        'Понтонный', 'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет',
#        'Сланцы', 'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка',
# ...

# %%
df['locality_name'].value_counts()
# Out:
# Санкт-Петербург                       15721
# Мурино                                  590
# Кудрово                                 472
# Шушары                                  440
# Всеволожск                              398
#                                       ...
# городского типа Кондратьево               1
# Гладкое                                   1
# Семиозерье                                1
# Коммунары                                 1
# при железнодорожной станции Вещево        1
# Name: locality_name, Length: 321, dtype: int64

# %%
# заполним пропущенные значения в столбце средним расстоянием до аэропорта в данном населенном пункте (включая Санкт-Петербург)
df['airports_nearest'] = df.groupby('locality_name')['airports_nearest'].transform(lambda x: x.fillna(x.mean()))

# %%
# проверим количество пропущенных значений столбца
df['airports_nearest'].isna().sum()
# Out:
# 4829

# %% [markdown]
# **Выводы**: Устранили неявные дубликаты в столбце locality_name(количество значений сократилось с 364 до 325), а также заполнили средним значением расстояние до аэропорта в зависимости от населенного пункта. Незаполненными остались значения для 4864 строк, оставим их без изменений.

# %% [markdown]
# ### Колонка balcony.

# %%
# по всем пропущенным объектам заполним значением 0
df['balcony'] = df['balcony'].fillna(0)

# %%
# переведем все значения колонки в int
df['balcony'] = df['balcony'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        14490 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
# проверим количество уникальных значений столбца
df['balcony'].value_counts()
# Out:
# 0    15238
# 1     4187
# 2     3658
# 5      304
# 4      182
# 3       81
# Name: balcony, dtype: int64

# %%
# проверим пропуски
df['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Выводы**: количество балконов может быть 0, 1, 2, 3, 4 и 5. При этом чаще всего объекты недвижимости представлены без балкона, либо с 1, или 2 балконами.

# %% [markdown]
# ### Колонка ceiling_height

# %%
# заполним пропущенные значения колонки средним значением для указанного количества комнат
df['ceiling_height'] = df.groupby('rooms')['ceiling_height'].transform(lambda x: x.fillna(x.median()))

# %%
# промежуточная проверка данных
df['ceiling_height'].isna().sum()
# Out:
# 1

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.60    4724
# 2.50    3515
# 2.64    3506
# 2.65    2688
# 2.70    1572
#         ...
# 3.76       1
# 4.90       1
# 5.20       1
# 2.89       1
# 4.65       1
# Name: ceiling_height, Length: 183, dtype: int64

# %% [markdown]
# **Выводы**: Данная колонка была заполнена медианным значением в зависимости от числа комнат, т.к. исходили из предположения, что среднее значение высоты потолков может быть рассчитано, как медиана по квартирам со схожими планировками (и с одинаковым количеством комнат). В качестве точки отсчета выбрана имено медиана для минимизации влияния единичных уникальных объектов с высотой потолков в 5-10 метров.

# %% [markdown]
# ### Колонка floors_total.

# %% [markdown]
# Сопоставим незаполненные значения floors_total со значением floor, исходя из предположения, что количество этажей не может быть меньше, чем этаж продаваемой квартиры.

# %%
# заменим пустые значения на соответствующие из столбца floor
df['floors_total'] = df.fillna(df['floor'])

# %%
# промежуточная проверка
df['floors_total'].isna().sum()
# Out:
# 0

# %%
# рассмотрим количество уникальных значений в столбце
df['floors_total'].value_counts()
# Out:
# 10    1793
# 9     1723
# 20    1690
# 8     1581
# 7     1515
# 6     1479
# 11    1361
# 5     1299
# 12    1223
# 0     1058
# 13    1012
# 4      986
# 14     986
# 15     948
# 1      870
# 3      763
# 16     761
# 17     649
# 18     642
# 2      634
# 19     602
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 28       4
# 32       4
# 29       3
# 50       3
# 27       2
# 30       2
# 31       2
# 35       2
# 25       1
# 37       1
# 39       1
# 42       1
# Name: floors_total, dtype: int64

# %%
df['floors_total'] = df['floors_total'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23649 non-null  float64
#  6   floors_total          23650 non-null  int64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          2760 non-null   object
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# **Выводы**: заполнены пропуски в общем количестве этажей в здании значением этажа продажи квартиры, необходимо отметить, что представленные данные не достаточно точны, но количество замен было 86, что не должно в большой степени повлиять на конечные данные. Также изменен тип данных столбца на Int (в данном случае корректнее оперировать целыми числами, т.к. описывается общее количество этажей). Значения в 40-50 этажей не считаются ошибкой в данном df, т.к. в Санкт - Петербурге присутствуют здания с таким и более количеством этажей.

# %% [markdown]
# ### Колонка city_centers_nearest

# %% [markdown]
# В данной колонке более 5 тыс.пропусков, заполним по аналогии со столбцом airport_nearest в зависимости от locality_name.

# %%
# заполним пропущенные значения в столбце средним расстоянием до центра в данном населенном пункте (включая Санкт-Петербург)
df['city_centers_nearest'] = df.groupby('locality_name')['city_centers_nearest'].transform(lambda x: x.fillna(x.mean()))

# %%
# проверим количество пропущенных значений столбца
df['city_centers_nearest'].isna().sum()
# Out:
# 4829

# %% [markdown]
# **Выводы**: Можно заметить определенную тенденцию, по которой количество незаполненных данных по расстоянию до центра и расстоянию до аэропорта после заполнения средним значением для данного населенного пункта одинаково и составляет 4864 значения.

# %% [markdown]
# ### Колонка is_apartment.

# %%
# рассмотрим данную колонку по значениям
df['is_apartment'].value_counts()
# Out:
# False    2710
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Апартаменты отличаются от квартиры-студии (судя по описанию из открытых источников), типом помещения: апартаменты были переоборудованы из ранее нежилого помещения в жилое для временного или постоянного проживания. Судя по имеющимся данным, и их распределению, можно сделать вывод, что пропущенные сведения в колонке is_apartment могут быть заполнены значениями False и тип данных приведен к булевому.

# %%
# заполним пропущенные значения как False
df['is_apartment'] = df['is_apartment'].fillna('False')

# %%
# переведем в булев тип данных
df['is_apartment'] = df['is_apartment'].astype('bool')

# %%
# проверим пропуски
df['is_apartment'].isnull().sum()
# Out:
# 0

# %%
# проверим тип данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float64
#  2   total_area            23650 non-null  float64
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23649 non-null  float64
#  6   floors_total          23650 non-null  int64
#  7   living_area           21752 non-null  float64
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          21381 non-null  float64
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# **Выводы**: Изменен тип данных, количество аппартаментов составляет лишь 50 наименований, что не оказывает значительного влияния на итоговый результат исследования.

# %% [markdown]
# ### Колонка kitchen_area.

# %% [markdown]
# Рассмотрим колонку kitchen_area подробнее. Если учитывать, что квартиры-студии не имеют выделенной кухни, то для таких помещений поставим соответствующее значение в 0 м2.

# %%
df['kitchen_area'].describe()
# Out:
# count    21381.000000
# mean        10.566403
# std          5.901753
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
df['kitchen_area'].hist(bins=50)
plt.show()

# %% [markdown]
# Минимальное значение в 1,3 м2 для кухни является явной ошибкой. Основываясь на данных нормативных документов (https://docs.cntd.ru/document/1200035248), минимальный размер кухни в жилом помещении (за исключением квартиры-студии, где площадь кухни должна быть 0 и апартаментов, где размер кухни не нормируется) должен составлять не менее 5 м2. Проверим количество квартир с кухней менее 5 м2.

# %%
kitchen_area_min_5 = df.query('kitchen_area < 5')
kitchen_area_min_5
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 76               12   2800000.0        55.1  2016-05-14T00:00:00      3
# 298               9   2650000.0        42.8  2017-04-25T00:00:00      2
# 422               8   1700000.0        55.2  2018-03-24T00:00:00      3
# 906              15   2600000.0        27.0  2017-07-10T00:00:00      1
# 1327              6   2650000.0        46.2  2016-12-01T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 22839            14   3350000.0        27.0  2018-11-03T00:00:00      1
# 22849             6   2380000.0        25.0  2016-03-22T00:00:00      1
# 23110             1   2900000.0        34.0  2018-02-01T00:00:00      2
# 23498             7   1600000.0        54.0  2016-12-26T00:00:00      2
# 23678            10   3500000.0        43.0  2016-05-19T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# После выборки мы имеем 105 строк со значениями кухни, которые не соответствуют требованиям нормативных документов для жилых помещений. Рассмотрим параметры данной выборки.

# %%
# описание значений для кухни менее 5 метров
kitchen_area_min_5['kitchen_area'].describe()
# Out:
# count    105.000000
# mean       3.996095
# std        0.852713
# min        1.300000
# 25%        3.800000
# 50%        4.000000
# 75%        4.700000
# max        4.900000
# Name: kitchen_area, dtype: float64

# %%
kitchen_area_min_5['kitchen_area'].value_counts()
# Out:
# 4.00    25
# 4.90    12
# 4.80    11
# 4.50     9
# 2.00     7
# 3.00     7
# 4.70     6
# 4.60     4
# 3.50     4
# 4.20     3
# 4.10     3
# 3.80     3
# 4.40     2
# 2.89     1
# 3.20     1
# 2.30     1
# 2.40     1
# 1.30     1
# 3.70     1
# 3.30     1
# 3.40     1
# 4.30     1
# Name: kitchen_area, dtype: int64

# %%
# проверим, в аппартаментах ли размещены кухни с размерами меньше 5 м2
kitchen_area_min_5[kitchen_area_min_5['is_apartment'] == False]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2684             18   2650000.0        31.0  2017-04-09T00:00:00      1
# 5193             17   2550000.0        27.0  2017-04-17T00:00:00      1
# 5415             16   8200000.0        60.0  2015-12-16T00:00:00      3
# 6810             10   1920000.0        29.0  2016-05-07T00:00:00      2
# 7436             17   2890000.0        57.1  2016-02-26T00:00:00      3
# 7950              3   5967734.0        66.4  2017-02-07T00:00:00      2
# 9873              3   2800000.0        35.0  2017-05-08T00:00:00      1
# 10208             3   1900000.0        17.0  2018-08-14T00:00:00      1
# 17071             5   3700000.0        27.0  2016-04-10T00:00:00      1
# 20321             9   4300000.0        34.0  2016-07-04T00:00:00      2
# 22839            14   3350000.0        27.0  2018-11-03T00:00:00      1
# 23498             7   1600000.0        54.0  2016-12-26T00:00:00      2
# ...

# %% [markdown]
# Из 105 строк с кухней, размер которой не соответствует требованиям нормативных документов для жилых помещений (не распространяется на аппартаменты), осталось лишь 12 строк. Половина из них - это однокомнатные квартиры. Вероятнее всего, данные по размерам кухни в данных 12 строках указаны ошибочно, их процент в общем количестве невелик, оставим без изменений.
#
# Исключим данные значения из расчетов среднего значения по площади кухни и рассмотрим параметры оставшихся данных.

# %%
kitchen_area_more_5m = df.query('kitchen_area >= 5')

# %%
kitchen_area_more_5m['kitchen_area'].describe()
# Out:
# count    21276.000000
# mean        10.598828
# std          5.897875
# min          5.000000
# 25%          7.000000
# 50%          9.200000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Минимальное значение оставшихся размеров составляет норматив в 5 м2, при этом квантили распределения практически не изменились (медиана с 9,1 м2 сдвинулась в большую сторону в 9,2 м2). Рассмотрим другую сторону распределения, не минимальные, а максимальные значения (судя по имеющимся сведениям, кухня может быть 112 м2, но это значение достаточно велико, возможно возникновение ошибки). Оценим количество и распределение размеров кухни.

# %%
kitchen_area_more_5m['kitchen_area'].value_counts()
# Out:
# 6.00     1298
# 10.00    1259
# 8.00     1108
# 9.00     1100
# 7.00     1062
#          ...
# 7.12        1
# 13.73       1
# 14.74       1
# 53.10       1
# 16.74       1
# Name: kitchen_area, Length: 946, dtype: int64

# %%
# рассмотрим срез кухонь более 20 м2
kitchen_area_more_5m[kitchen_area_more_5m['kitchen_area'] >=20]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# 51                7  45000000.0      161.00  2017-10-17T00:00:00      3
# 61               18   7990000.0       74.00  2017-08-24T00:00:00      2
# 106               9  10500000.0      124.10  2017-05-25T00:00:00      5
# ...             ...         ...         ...                  ...    ...
# 23491            20  21800000.0      250.00  2017-09-16T00:00:00      3
# 23507             4   7360000.0       73.83  2018-06-23T00:00:00      2
# 23549             5  19600000.0      184.00  2016-04-21T00:00:00      3
# 23590             0  21187872.0      123.30  2017-04-25T00:00:00      3
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Данные значения выглядят достаточно правдоподобно, рассмотрим отдельно строки от 50 и выше м2, и включают в себя 1154 строки.

# %%
kitchen_area_more_5m[kitchen_area_more_5m['kitchen_area'] >=50]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 51                7   45000000.0       161.0  2017-10-17T00:00:00      3
# 492              18   95000000.0       216.0  2017-12-05T00:00:00      4
# 511               7    5950000.0        69.0  2017-12-21T00:00:00      1
# 656              10   18500000.0       131.0  2018-10-11T00:00:00      3
# 793              20  135000000.0       310.0  2018-05-22T00:00:00      4
# 1026             20  155000000.0       310.0  2018-10-12T00:00:00      5
# 1085             16   75000000.0       323.0  2017-07-10T00:00:00      5
# 2356             11   50000000.0       128.0  2016-06-24T00:00:00      3
# 2489              9   12500000.0       255.0  2017-04-21T00:00:00      3
# 3117             19  140000000.0       631.0  2019-03-30T00:00:00      7
# 3561              5   12300000.0       115.0  2017-08-09T00:00:00      3
# 4320             20   19700000.0       146.3  2017-02-10T00:00:00      3
# ...

# %% [markdown]
# Рассмотрев полученные 55 строк, можно выявить, что данные выглядят достаточно прапвдоподобно и, например, для максимального размера кухни в 112 м2, общая площадь помещения составила 900 м2.

# %% [markdown]
# Заполним пропущенные значения медианным значением в зависимости от общей площади помещения(в данном столбце нет пропусков).

# %%
# заполнение пропусков медианным значением
df['kitchen_area'] = df.groupby('total_area')['kitchen_area'].transform(lambda x: x.fillna(x.median()))

# %%
# общее описание столбца
df['kitchen_area'].describe()
# Out:
# count    23445.000000
# mean        10.454360
# std          5.779649
# min          1.300000
# 25%          7.000000
# 50%          9.000000
# 75%         11.800000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %%
df['kitchen_area'].isnull().sum()
# Out:
# 205

# %% [markdown]
# Незаполненными остались 205 строк. Вероятнее всего, для помещений данного размера в данных не было приведено ни одного значения площади кухни.

# %%
#рнассмотрим изменения в гистограмме
df['kitchen_area'].hist(bins=50)
plt.show()

# %% [markdown]
# **Выводы**: Заполнили пропущенные значения, проверили зависимость размеров кухни от типа помещения и соотнесли медианное значение по общему размеру помещения и размеры кухни. Минимальный размер указанной кухни 1,3 м2 не соответствует требованиям нормативных документов (на их основании считаем, что  размер кухни от 5 м2 ), но значения минимальных размеров кухонь в большинстве случаев относятся к аппартаментам, в которых данные параметры не регламентируются. Значения размеров кухни после заполнения пропусков (среднее, минимум, максимум и точки-квантили) практически не изменились. Необходимо отметить, что по 205 объектам значения заполнить так и не удалось.

# %% [markdown]
# ### Колонка living_area.

# %% [markdown]
# Рассмотрим колонку living_area подробнее, учитывая описание. Будем руководствоваться гипотезой, что в зависимости от размера помещения можно будет заполнить пропуски по данной колонке.

# %%
df['living_area'].describe()
# Out:
# count    21752.000000
# mean        34.448356
# std         22.037664
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
df['living_area'].hist(bins=100)
plt.show()

# %% [markdown]
# Получаем достаточно интересные значения, при которых минимальная площадь жилой площади поменения оценивается в 2 м2. Обратимся к нормативным документам. Минимальный размер жилого помещения для продажи в Санкт - Петербурге составляет 9 м2 (https://gu.spb.ru/help/usefulinfo/Zhilishchnyj-uchet/)

# %%
# определим количество продаваемой жилой недвижимости с общим размером жилой площади менее 9 м2.
living_area_min_9 = df.query('living_area < 9')
living_area_min_9
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 114               5   4000000.0        21.4  2019-02-07T00:00:00      1
# 2309             10   4200000.0        62.4  2017-06-15T00:00:00      2
# 3242              7   4440000.0        41.0  2017-07-02T00:00:00      1
# 13915            20   6350000.0        52.0  2018-02-06T00:00:00      2
# 16431            13   3799000.0        31.0  2018-04-12T00:00:00      1
# 17248            20   5300000.0        33.0  2017-04-14T00:00:00      1
# 17582            11   2680000.0        22.0  2018-08-11T00:00:00      0
# 19251            19   4050000.0        33.0  2018-10-15T00:00:00      1
# 20994             7   8900000.0        50.6  2018-10-22T00:00:00      2
# 21505             9   4100000.0        35.3  2018-01-10T00:00:00      1
# 21758             0   2330000.0        23.0  2018-01-01T00:00:00      0
# 21943            15   6100000.0        77.6  2019-02-28T00:00:00      4
# ...

# %% [markdown]
# Судя по данным таблицы, таких помещений всего 14. Значительного влияния на данные такой небольшой процент ошибочных данных не окажет.
# Но, для проверки, рассмотрим параметры распределения без этих данных.

# %%
living_area_more_9m = df.query('living_area >= 9')

# %%
living_area_more_9m['living_area'].describe()
# Out:
# count    21738.000000
# mean        34.466723
# std         22.032778
# min          9.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
living_area_more_9m['living_area'].value_counts()
# Out:
# 18.00    882
# 17.00    674
# 30.00    598
# 16.00    485
# 20.00    479
#         ...
# 50.26      1
# 43.81      1
# 54.43      1
# 86.10      1
# 16.74      1
# Name: living_area, Length: 1771, dtype: int64

# %% [markdown]
# Параметры распределения не изменились, влияния на среднее и медианное значение не оказано.
#
# Максимальное значение жилого помещения составляет 409,7 м2. Рассмотрим помещения с размерами жилой части более 300 м2.

# %%
# срез жилых помещений с площадью более 300 м2.
living_area_more_9m[living_area_more_9m['living_area'] >=300]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 660               3   49950000.0       483.9  2017-10-04T00:00:00      7
# 4237              1   50000000.0       517.0  2017-10-14T00:00:00      7
# 5358             20   65000000.0       590.0  2019-02-14T00:00:00     15
# 8018             20   84000000.0       507.0  2015-12-17T00:00:00      5
# 12401            20   91500000.0       495.0  2017-06-19T00:00:00      7
# 12859            20  140000000.0       631.2  2019-04-09T00:00:00      7
# 14088             8   51000000.0       402.0  2017-02-07T00:00:00      6
# 19540             8  420000000.0       900.0  2017-12-06T00:00:00     12
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 660              3.20             3        312.5      4          True  ...
# 4237             3.38             1        332.0      3          True  ...
# 5358             3.50            20        409.0      3          True  ...
# ...

# %% [markdown]
# Таких объектов недвижимости оказалось всего 8 и их площадь равномерно соотносится с общей площадью помещения.
#
# Заполним пропущенные значения в столбце, медианным значеним по квартирам с такой же общей площадью.

# %%
# заполнение пропусков медианным значением
df['living_area'] = df.groupby('total_area')['living_area'].transform( lambda x: x.fillna(x.median()))

# %%
# общее описание столбца
df['living_area'].describe()
# Out:
# count    23507.000000
# mean        34.454393
# std         21.841437
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.255000
# max        409.700000
# Name: living_area, dtype: float64

# %%
df['living_area'].isnull().sum()
# Out:
# 143

# %%
df['living_area'].hist(bins=100)
plt.show()

# %% [markdown]
# Проверим гипотезу, что сумма кухни и жилой площади должна быть меньше, чем общая площадь недвижимости. Для этого, введем новый столбец area_sum с типом данных - булев тип и проверим количество True и False ячеек.

# %%
df['area_sum'] = ((df['kitchen_area']+ df['living_area']) < df['total_area'])

# %%
df['area_sum'].value_counts()
# Out:
# True     23160
# False      490
# Name: area_sum, dtype: int64

# %% [markdown]
# Мы получили 490 квартир, в которых значение суммы жилой площади и площади кухни больше либо равно общей площади помещения (что противоречит строительным нормам). Вероятнее всего, при заполнении средними значениями (с соотношением общей площади) значений в столбцах кухни и жилой площади были допущены отклонения. Их объем составляет 2,12% от общего числа проанализированных квартир, будем иметь в ввид полученные данные, но серьезного влияния на результаты исследования параметр не оказывает. Принимаем верной гипотезу о возможности заполнения пропущенных значений медианными в зависимости от группировки по общей площади.

# %% [markdown]
# **Выводы**: Было установлено соответствие между общими размерами помещения и жилой площадью, пропущенные данные были заполнены медианным значением. Средняя площадь помещения изменилась и составила 34,45 м2 (вместо 34,46 м2 изначально), медианное значение с 22 м2 изменилось др 21,8 м2, что свидетельствует о незначительном влиянии пропущенных значений.

# %% [markdown]
# ### Колонки parks_around_3_km и parks_nearest.

# %% [markdown]
# В данных столбцах df указаны значения о количестве парков вокруг на расстоянии в пределах 3 км и в расстоянии до парков в целом. Примем гипотезу, что если в столбце parks_around_3000 значение не 0, то расстояние до парка (если оно не заполнено) становится средним по региону.
# Учтем, что количество парков может быть только целым числом, а так же рассмотрим данные колонки более подробно.

# %%
# заполним пропущенные значения столбца parks_around_3_km нулем
df['parks_around_3_km'] = df['parks_around_3_km'].fillna(0)

# %%
# переведем значения столбца parks_around_3_km в целочисленные.
df['parks_around_3_km'] = df['parks_around_3_km'].astype(int)

# %%
# проверим распределение значений по количеству парков
df['parks_around_3_km'].value_counts()
# Out:
# 0    15590
# 1     5671
# 2     1744
# 3      645
# Name: parks_around_3_km, dtype: int64

# %% [markdown]
# Следующим шагом подобным образом рассмотрим столбец parks_nearest.

# %%
df['parks_nearest'].value_counts()
# Out:
# 441.0     67
# 392.0     41
# 173.0     41
# 456.0     40
# 471.0     32
#           ..
# 863.0      1
# 828.0      1
# 1909.0     1
# 1049.0     1
# 929.0      1
# Name: parks_nearest, Length: 994, dtype: int64

# %%
df['parks_nearest'].hist(bins=100)
plt.show()

# %%
# рассмотрим описание данных распределения
df['parks_nearest'].describe()
# Out:
# count    8064.000000
# mean      490.830729
# std       342.554386
# min         1.000000
# 25%       288.000000
# 50%       454.500000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Распределение достаточно ярко выражено, значения свыше 1000 метров уже встречаются достаточно редко.

# %%
# заполним значения средним по данному населенному пункту
df['parks_nearest'] = df.groupby('locality_name')['parks_nearest'].transform(lambda x: x.fillna(x.median()))

# %%
df['parks_nearest'].isnull().sum()
# Out:
# 5998

# %% [markdown]
# **Выводы**: вместо незаполненных 15620 осталось 5998 значений. Оставшиеся пропуски оставим без изменений.

# %% [markdown]
# ### Колонки ponds_around_3_km и ponds_nearest.

# %% [markdown]
# В данных столбцах df указаны значения о количестве прудов вокруг на расстоянии в пределах 3 км и в расстоянии до данных водоемов в целом. Примем гипотезу, что если в столбце ponds_around_3_km значение не 0, то расстояние до пруда (если оно не заполнено) становится средним по данному региону.
# Учтем, что количество прудов может быть только целым числом, а так же рассмотрим данные колонки более подробно.
# Проведем те же этапы анализа, что и в предыдущем подразделе.

# %%
# заполним пропущенные значения столбца ponds_around_3_km нулем
df['ponds_around_3_km'] = df['ponds_around_3_km'].fillna(0)

# %%
# переведем значения столбца ponds_around_3000 в целочисленные.
df['ponds_around_3_km'] = df['ponds_around_3_km'].astype(int)

# %%
# проверим распределение значений по количеству прудов
df['ponds_around_3_km'].value_counts()
# Out:
# 0    14565
# 1     5702
# 2     1889
# 3     1494
# Name: ponds_around_3_km, dtype: int64

# %%
df['ponds_nearest'].value_counts()
# Out:
# 427.0     70
# 454.0     41
# 153.0     40
# 433.0     39
# 474.0     37
#           ..
# 986.0      1
# 156.0      1
# 914.0      1
# 1168.0     1
# 995.0      1
# Name: ponds_nearest, Length: 1096, dtype: int64

# %%
df['ponds_nearest'].hist(bins=100)
plt.show()

# %%
# рассмотрим описание данных распределения
df['ponds_nearest'].describe()
# Out:
# count    9085.000000
# mean      518.059879
# std       277.841733
# min        13.000000
# 25%       293.000000
# 50%       502.000000
# 75%       730.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %%
# заполним значения средним по данному населенному пункту
df['ponds_nearest'] = df.groupby('locality_name')['ponds_nearest'].transform(lambda x: x.fillna(x.median()))

# %%
df['ponds_nearest'].isnull().sum()
# Out:
# 4938

# %% [markdown]
# **Выводы**: вместо незаполненных 14589 осталось 4972 значений. Оставшиеся пропуски оставим без изменений.

# %% [markdown]
# ### Выводы.

# %%
#сменим тип данных с float64 на float32
category_64 = [
    'last_price', 'total_area', 'ceiling_height', 'living_area',
               'kitchen_area', 'airports_nearest', 'city_centers_nearest', 
               'parks_nearest', 'ponds_nearest', 'days_exposition'
              ]
for column in category_64:
    df[column] = df[column].astype('float32')

# %%
# рассмотрим общее описание по df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23650 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23650 non-null  int64
#  1   last_price            23650 non-null  float32
#  2   total_area            23650 non-null  float32
#  3   first_day_exposition  23650 non-null  object
#  4   rooms                 23650 non-null  int64
#  5   ceiling_height        23649 non-null  float32
#  6   floors_total          23650 non-null  int64
#  7   living_area           23507 non-null  float32
#  8   floor                 23650 non-null  int64
#  9   is_apartment          23650 non-null  bool
#  10  studio                23650 non-null  bool
#  11  open_plan             23650 non-null  bool
#  12  kitchen_area          23445 non-null  float32
#  13  balcony               23650 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %%
# рассмотрим описание всех столбцов df
df.describe()
# Out:
#        total_images   last_price    total_area         rooms  ceiling_height  \
# count  23650.000000      23650.0  23650.000000  23650.000000    23649.000000
# mean       9.862326    6541126.5     60.329071      2.070106        2.722502
# std        5.682278   10896399.0     35.661808      1.078620        0.990669
# min        0.000000      12190.0     12.000000      0.000000        1.000000
# 25%        6.000000    3400000.0     40.000000      1.000000        2.600000
# 50%        9.000000    4650000.0     52.000000      2.000000        2.640000
# 75%       14.000000    6799000.0     69.699997      3.000000        2.700000
# max       50.000000  763000000.0    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23650.000000  23507.000000  23650.000000  23445.000000  23650.000000
# mean       9.862326     34.454391      5.893277     10.454360      0.591712
# ...

# %%
# выведем первые 10 строк df
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0  108.000000  2019-03-07T00:00:00      3
# 1             7   3350000.0   40.400002  2018-12-04T00:00:00      1
# 2            10   5196000.0   56.000000  2015-08-20T00:00:00      2
# 3             0  64900000.0  159.000000  2015-07-24T00:00:00      3
# 4             2  10000000.0  100.000000  2018-06-19T00:00:00      2
# 5            10   2890000.0   30.400000  2018-09-10T00:00:00      1
# 6             6   3700000.0   37.299999  2017-11-02T00:00:00      1
# 7             5   7915000.0   71.599998  2019-04-18T00:00:00      2
# 8            20   2900000.0   33.160000  2018-05-23T00:00:00      1
# 9            18   5400000.0   61.000000  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            20    51.000000      8          True  ...
# 1            2.64             7    18.600000      1          True  ...
# ...

# %%
# выведем последние 10 строк df
df.tail(10)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23689            13   3550000.0   35.299999  2018-02-28T00:00:00      1
# 23690             3   5500000.0   52.000000  2018-07-19T00:00:00      2
# 23691            11   9470000.0   72.900002  2016-10-13T00:00:00      2
# 23692             2   1350000.0   30.000000  2017-07-07T00:00:00      1
# 23693             9   4600000.0   62.400002  2016-08-05T00:00:00      3
# 23694             9   9700000.0  133.809998  2017-03-21T00:00:00      3
# 23695            14   3100000.0   59.000000  2018-01-15T00:00:00      3
# 23696            18   2500000.0   56.700001  2018-02-11T00:00:00      2
# 23697            13  11475000.0   76.750000  2017-03-28T00:00:00      2
# 23698             4   1350000.0   32.299999  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 23689            2.86            13    16.299999      4          True  ...
# ...

# %%
# проверим df на пропущенные значения
df.isnull().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             1
# floors_total               0
# living_area              143
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area             205
# balcony                    0
# locality_name              0
# airports_nearest        4829
# city_centers_nearest    4829
# parks_around_3_km          0
# parks_nearest           5998
# ponds_around_3_km          0
# ponds_nearest           4938
# days_exposition         3180
# area_sum                   0
# dtype: int64

# %% [markdown]
# **Выводы**: в данном разделе были приведены в соответствие с правилами указания названий 3 столбца, максимально возможно заполнены пропуски, колонки: floors_total, ponds_around_3_km, parks_around_3_km, приведены к целочисленным значениям, колонка is_apartments - к булевым. Данные предварительно обработаны и готовы к дальнейшему анализу, сокращено количество пропусков данных. Данные во всех колонках со значениями float64 переведены во float32 для экономии памяти.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу.

# %% [markdown]
# ### Расчет цены квадратного метра.

# %% [markdown]
# Для выполнения работ по дальнейшему анализу добавим столбец со стоимостью м2 для каждого отдельного объекта (разделим значения столбца last_price на количество квадратных метров total_area для каждой строки и округлим полученное значение до двух знаков после запятой(цена в руб.)

# %%
# добавим столбец price_metr о цене за м2
df['price_metr'] = df['last_price'] / df['total_area']

# %%
# округлим до сотых долей (цена в руб/м2 более высокая точность не целесообразна)
df['price_metr'].round(2)
# Out:
# 0        120370.367188
# 1         82920.789062
# 2         92785.710938
# 3        408176.093750
# 4        100000.000000
#              ...
# 23694     72490.843750
# 23695     52542.371094
# 23696     44091.710938
# 23697    149511.406250
# 23698     41795.671875
# Name: price_metr, Length: 23650, dtype: float32

# %%
df['price_metr'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### День недели, месяц и год публикации объявления.

# %% [markdown]
# Разобъем данный столбец на отдельные значения

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'])

# %%
# создадим столбцы для дня недели, месяца и года публикации объявления
df['week_day_exposition'] = df['first_day_exposition'].dt.weekday
df['month_exposition'] = df['first_day_exposition'].dt.month
df['year_exposition'] = df['first_day_exposition'].dt.year

# %% [markdown]
# ### Категоризация этажа квартиры (первый, последний, другой).

# %% [markdown]
# Создадим функцию category_floor, которая поможет быстро распределить значения данного столбца по категориям.

# %%
# функция для распределения этажей по категориям первый, последний, другой
def category_floor(row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

# %%
# применим созданную функцию к df, данные категории определим в отдельный столбец floor_category
df['floor_category'] = df.apply(category_floor, axis=1)

# %%
# выведем число уникальных значений столбца
df['floor_category'].value_counts()
# Out:
# другой       19844
# первый        2912
# последний      894
# Name: floor_category, dtype: int64

# %% [markdown]
# ### Соотношение жилой и общей площади.

# %% [markdown]
# Создадим новый столбец living_total_correlation и округлим полученное соотношение.

# %%
df['living_total_correlation'] = df['living_area'] / df['total_area']

# %%
# округлим до двух знаков после запятой
df['living_total_correlation'] = df['living_total_correlation'].round(2)

# %%
# описание столбца living_total_correlation
df['living_total_correlation'].describe()
# Out:
# count    23507.000000
# mean         0.565198
# std          0.102815
# min          0.020000
# 25%          0.500000
# 50%          0.570000
# 75%          0.630000
# max          1.000000
# Name: living_total_correlation, dtype: float64

# %%
df['living_total_correlation'].isna().sum()
# Out:
# 143

# %%
df['living_total_correlation'].value_counts()
# Out:
# 0.62    1080
# 0.60    1009
# 0.56     976
# 0.55     966
# 0.59     946
#         ...
# 0.09       1
# 0.13       1
# 0.14       1
# 0.99       1
# 0.22       1
# Name: living_total_correlation, Length: 91, dtype: int64

# %% [markdown]
# ### Соотношение площади кухни к общей.

# %% [markdown]
# Создадим новый столбец kitchen_total_correlation и округлим полученное соотношение.

# %%
df['kitchen_total_correlation'] = df['kitchen_area'] / df['total_area']

# %%
# округлим до двух знаков после запятой
df['kitchen_total_correlation'] = df['kitchen_total_correlation'].round(2)

# %%
# описание столбца kichen_total_correlation 
df['kitchen_total_correlation'].describe()
# Out:
# count    23445.000000
# mean         0.186736
# std          0.071319
# min          0.030000
# 25%          0.140000
# 50%          0.170000
# 75%          0.230000
# max          0.790000
# Name: kitchen_total_correlation, dtype: float64

# %%
df['kitchen_total_correlation'].isna().sum()
# Out:
# 205

# %%
df['kitchen_total_correlation'].value_counts()
# Out:
# 0.14    1804
# 0.16    1668
# 0.15    1595
# 0.12    1475
# 0.13    1447
#         ...
# 0.64       1
# 0.61       1
# 0.79       1
# 0.60       1
# 0.66       1
# Name: kitchen_total_correlation, Length: 66, dtype: int64

# %% [markdown]
# ### Выводы

# %% [markdown]
# Были созданы несколько новых столбцов, описывающих цену квадратного метра, выделяющие в отдельный столбец день недели, месяц и год публикации, была проведена категоризация квартир по соотношению этажей (первый, последний, другой), рассчитаны соотношения жилого помещения к общей площади объекта недвижимости и соответственно кухни к общей площади.

# %% [markdown]
# ## Исследовательский анализ данных.

# %% [markdown]
# ### Изучение параметров квартир.

# %% [markdown]
# #### Площадь.

# %% [markdown]
# Рассмотрим значения и описание данного параметра квартиры и построим диаграмму рассеивания и гистограмму.

# %%
# описание данных столбца с общей площадью
df['total_area'].describe()
# Out:
# count    23650.000000
# mean        60.329071
# std         35.661808
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.699997
# max        900.000000
# Name: total_area, dtype: float64

# %%
# диаграмма ящик для столбца total_area
df.boxplot(column='total_area')
plt.show()

# %% [markdown]
# График выглядит достаточно скученно, имеется некоторое количество выбросов (высокий размер площади). Удалим выбросы и рассмотрим на графике распределение размеров квартир.

# %%
df.boxplot(column='total_area', showfliers = False)
plt.show()

# %% [markdown]
# Построим гистограмму распределения значений данного столбца.

# %%
# гистограмма распределения total_area
df['total_area'].hist(bins=100, range=(10, 100), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Вывод**: Распределение позволяет заметить, что первый пик по распределению общей площади квартир приходится на 30 м2, максимальное количество квартир площадью окло 45 м2, следующий пик приходится на 60 м2 и далее убывание количества квартир при увеличении площади. Квартир с небольшой площадью, особенно менее 25, представлено минимальное значение. Перестроим гистограмму, задав диапазон от 25 до 90 м2.

# %%
# гистограмма распределения total_area
df['total_area'].hist(bins=100, range=(25, 90), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# #### Цена.

# %% [markdown]
# Рассмотрим значения и описание ценового параметра квартир и построим диаграмму рассеивания и гистограмму.

# %%
# описание данных столбца с ценой за квартиру
df['last_price'].describe()
# Out:
# count        23650.0
# mean       6541126.5
# std       10896399.0
# min          12190.0
# 25%        3400000.0
# 50%        4650000.0
# 75%        6799000.0
# max      763000000.0
# Name: last_price, dtype: float64

# %%
df['last_price'] = df['last_price'] / 1000000

# %%
# диаграмма ящик для столбца last_price
df.boxplot(column='last_price')
plt.show()

# %%
# диаграмма ящик для столбца last_price с исключением выбросов
df.boxplot(column='last_price', showfliers = False)
plt.show()

# %%
# гистограмма распределения last_price
df['last_price'].hist(bins=100, range=(0, 100), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# Распределение до 100 млн.выглядит недостаточно подробно. Снизим диапазон цен до 20 млн.руб.

# %%
# гистограмма распределения last_price
df['last_price'].hist(bins=100, range=(0, 20), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Вывод**: В данном распределении основной диапазон цен заключен между 2 и 8 млн.руб. Максимальное значение приходится на 3 миллиона рублей и на 4,8 миллионов рублей. Значения более 9 млн.рублей встречаются реже и происходит постепенное снижение, заметное на гистограмме.

# %% [markdown]
# #### Число комнат.

# %%
# описание данных столбца с количеством комнат
df['rooms'].describe()
# Out:
# count    23650.000000
# mean         2.070106
# std          1.078620
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
df['rooms'].value_counts()
# Out:
# 1     8036
# 2     7924
# 3     5797
# 4     1175
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 19       1
# 16       1
# 12       1
# 15       1
# Name: rooms, dtype: int64

# %%
# диаграмма рассеивания для столбца rooms с исключением выбросов
df.boxplot(column='rooms', showfliers = False)
plt.show()

# %%
# гистограмма распределения rooms с исключением количества комнат больше 6
df['rooms'].hist(bins=10, range=(0, 6), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Вывод**: Основываясь на представленном распределении можно обратить внимание, что максимальное количество продаж приходится на 1 и 2 комнатные квартиры (их значения практически равны и составляют 8036 и 7924 соответственно). Достаточно часто встречаются 3-х комнатные квартиры, количество квартир с комнатами более 4 резко снижается, квартиры с количеством комнат более 10 встречаются в практически единичных экземплярах.

# %% [markdown]
# #### Высота потолков.

# %%
# описание данных столбца с высотой потолков
df['ceiling_height'].describe()
# Out:
# count    23649.000000
# mean         2.722502
# std          0.990669
# min          1.000000
# 25%          2.600000
# 50%          2.640000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.60     4724
# 2.50     3515
# 2.64     3506
# 2.65     2688
# 2.70     1572
#          ...
# 2.34        1
# 2.25        1
# 4.25        1
# 10.30       1
# 4.30        1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
# диаграмма ящик для столбца высота потолков  с исключением вбросов
df.boxplot(column='ceiling_height', showfliers = False)
plt.show()

# %%
# гистограмма распределения значения высота потолков 
df['ceiling_height'].hist(bins=100, range=(1, 5), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# Распределение основных значений по высоте потолов сконцентрированно в диапазоне от 2,45 м до 2,85 м (согласно квантилям). Рассмотрим данный диапазон на гистограмме более подробно.

# %%
# гистограмма распределения значения высота потолков в диапазоне  2,45 - 2,85
df['ceiling_height'].hist(bins=100, range=(2.45, 2.85), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Вывод**: Больше всего квартир с высотой потолков в 2,5; 2,6; 2,63 метра. Все значения ниже 2,5 и выше 2,8 метра встречаются крайне редко (что обусловлено общими требованиями нормативной документации и особенностями проектирования жилых зданий в Санкт-Петербурге). Встречается высота потолков в 4 и выше метров, но это либо уникальный объекты, либо "старый" жилой фонд.

# %% [markdown]
# ### Время продажи квартиры.

# %% [markdown]
# В данном разделе рассмотрим непосредственное время продажи квартиры (в днях), оценим параметры колонки days_exposition и построим гистограмму по распределению времени продаж. В выводах по разделу необходимо будет ответить на вопрос задания: Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
# рассмотрим описание, медиану и среднее для времени продажи квартир
df['days_exposition'].describe()
# Out:
# count    20470.000000
# mean       180.753204
# std        219.777924
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
# диаграмма размаха
df.boxplot(column='days_exposition')
plt.show()

# %%
# диаграмма размаха с исключением выбросов
df.boxplot(column='days_exposition', showfliers = False)
plt.show()

# %%
# гистограмма распределения значения скорость продажи квартиры
df['days_exposition'].hist(bins=100, figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# Явно присутствует пиковое значение в районе 80 дней и "хвост" из значений в сроках продажи свыше 600. Рассмотрим гистограмму с данными ограничениями по диапазону значений.

# %%
# гистограмма распределения значения скорость продажи квартиры в диапазоне от 0 до 600 дней.
df['days_exposition'].hist(bins=100, range=(0, 600), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Выводы**: Все продажи, совершенные в период от 1 до 45 дней можно считать "быстрой сделкой". Таких сделок порядка 25% (на 45 дней приходится 1-й квантиль диаграммы размаха), за данный промежуток времени уровень продаж хоть и имеет пиковые значения, например, на 10-15 день, но внутри диапазона распределение выглядит как близкое к нормальному. Самое оптимальное время продаж может быть установлено, как сделка, совершившаяся в период от 45 до 200/220 дней (соответственно третий квантиль с захватом медианного значения в 95 дней и среднего в 180 дней). Сделки выше 500 дней (самый широкий диапазон диаграммы рассеяния), то, что выходит за рамки диаграммы, является "необычно долгими" сроками для сделки, т.е. объект недвижимости невозможно продать в течении двух и более лет.

# %% [markdown]
# ### Выбивающиеся значения и их влияние.

# %% [markdown]
# Выбивающиеся значения и их роль в представленных данных, а также предложения по исключению и минимизации их влияния на итоговый резульатат исследования были проверены по столбцам и описаны в соответствующих разделах данной аналитической работы (общий анализ данных в разделе 1 и весь раздел 2 по предобработке данных).

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры?

# %% [markdown]
# В данном подразделе расмотрим последовательно зависимость цены от площади, числа комнат, удалённости от центра. Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучим зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Зависимость цены от площади.

# %%
# построим точечную диаграмму зависимости цены от площади в диапазоне от 25 до 90 м2, как было рассмотрено в разделе 4.1.1.
df.plot(x='total_area', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
xlim=(10, 200))
# Out:
# <AxesSubplot:xlabel='total_area'>

# %% [markdown]
# **Вывод**: При анализе зависимости становится заметно, что зависимость выражена недостаточно ярко, при площади свыше 100 м2 становится все больше разброс по цене, так же встречаются резкие выбросы значений.

# %% [markdown]
# #### Зависимость цены от числа комнат.

# %%
# построим точечную диаграмму зависимости цены от числа комнат
df.plot(x='rooms', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
xlim=(0,10),
ylim=(0, 100000000))
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# **Вывод**: Основываясь на представленных данных, можно обратить внимание, что существует достаточно сильная зависимость между стоимостью и увеличением числа комнат, особенно это касается диапазона от 1 до 5 комнатных квартир, тогда как для 6 и более комнатных квартир данная зависимость спадает. Можно сделать вывод, что для квартир с количеством комнат менее 5 цена прямо пропорционально возрастает к числу комнат, тогда как для недвижимости с большим числом комнат такой зависимости нет.

# %% [markdown]
# #### Зависимость цены от удаленности от центра.

# %%
# построим точечную диаграмму зависимости цены от удаленности от центра
df.plot(x='city_centers_nearest', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 100000000))
# Out:
# <AxesSubplot:xlabel='city_centers_nearest'>

# %% [markdown]
# **Выводы**: Анализируя данный график становится очевидным обратная зависимость между расстоянием до центра населенного пункта и стоимостью квартиры, причем зависимость достаточно сильная, и чем дальше от центра населенного пункта, тем ниже стоимость квартиры.

# %% [markdown]
# #### Зависимость цены от этажа.

# %% [markdown]
# Выделено всего 3 категории этажей, проведем сортировку по данному признаку.

# %%
floor_sorted=df.groupby('floor_category')['last_price'].median()

# %%
# построим гистограмму зависимости цены от категории этажа
# используем метод по заданию в качестве оси х индексов нашей таблицы, а y -медианное значение последней цены продажи
floor_sorted.plot(x=floor_sorted.index, 
y=floor_sorted.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# **Вывод**: Самая низкая медианная цена приходится на первый этаж, тогда как медианные цены для последнего и других типов этажей практически одинаковы. На основании полученного сравнительного графика по сравнению медианных значений, делаем вывод о сниженной стоимости для объектов недвижимости, расположенных на первых этажах.

# %% [markdown]
# #### Зависимость цены от дня недели размещения.

# %% [markdown]
# Сгруппируем данные в зависимости от дня недели и построим гистограмму по медианным значениям для каждой группы значений.

# %%
# группировка по дням недели, определение медианы
weekdays_sorted=df.groupby('week_day_exposition')['last_price'].median()

# %%
# гистограмма распределения медианных значений
weekdays_sorted.plot(x=weekdays_sorted.index, 
y=weekdays_sorted.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='week_day_exposition'>

# %%
# построим точечную диаграмму зависимости цены от дня недели
df.plot(x='week_day_exposition', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 200000000))
# Out:
# <AxesSubplot:xlabel='week_day_exposition'>

# %% [markdown]
# **Вывод**: Не наблюдается определенная зависимость цены продажи квартиры от дня недели размещения.

# %% [markdown]
# #### Зависимость цены от месяца размещения объявления.

# %%
# группировка по месяцам, определение медианы
month_sorted=df.groupby('month_exposition')['last_price'].median()

# %%
# гистограмма распределения медианных значений
month_sorted.plot(x=month_sorted.index, 
y=month_sorted.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='month_exposition'>

# %%
# построим точечную диаграмму зависимости цены от месяца
df.plot(x='month_exposition', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 200000000))
# Out:
# <AxesSubplot:xlabel='month_exposition'>

# %% [markdown]
# **Вывод**: Можно отметить незначительные колебания цены продажи в зависимости от месяца, в который была выставлена на продажу недвижимость, но определенная зависимость не выявлена.

# %% [markdown]
# #### Зависимость цены от года размещения.

# %%
# группировка по годам, определение медианы
year_sorted=df.groupby('year_exposition')['last_price'].median()

# %%
# гистограмма распределения медианных значений
year_sorted.plot(x=year_sorted.index, 
y=year_sorted.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='year_exposition'>

# %%
# построим точечную диаграмму зависимости цены от года
df.plot(x='year_exposition', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 200000000))
# Out:
# <AxesSubplot:xlabel='year_exposition'>

# %% [markdown]
# **Вывод**: Максимальное медианное значение присутствовало в 2014 году, тогда как по графику распределения, более заметна зависимость по росту стоимости квартир к 2017 году(пиковое значение) и последующему снижению стоимость квартир в перид с 2017 по 2019 г, что позволяет сделать вывод, что зависимость стоимости продажи от года размещения присутствует.

# %% [markdown]
# #### Определение зависимости между параметрами цена, общая площадь, количество комнат и расстояние до центра.

# %%
df[['last_price', 'total_area', 'rooms', 'city_centers_nearest']].corr()
# Out:
#                       last_price  total_area     rooms  city_centers_nearest
# last_price              1.000000    0.653743  0.363421             -0.212859
# total_area              0.653743    1.000000  0.758745             -0.240638
# rooms                   0.363421    0.758745  1.000000             -0.197642
# city_centers_nearest   -0.212859   -0.240638 -0.197642              1.000000

# %% [markdown]
# Рассмотрим полученные результаты более подробно: цена продажи имеет высокую прямую зависимость от общей площади, тогда как зависимость от количества комнат более низкая, а от расстояния до центра - зависимость обратная, невыскоая, т.е. чем дальше объект недвижимости находится от центра, тем ниже его конечная цена.
# Общая площадь ожидаемо имеет высокую прямую зависимость от количества комнат, а также прямая достаточно высокая зависимость от цены продажи. С расстоянием до центра выявлена обратная несильно выраженная зависимость.
# Количество комнат имеет незначительную обратную завимость от расстояния до центра и прямую невысокую зависимость от цены продажи.

# %%
# отобразим полученные зависимости графически
df_corr=df.loc[:, ['last_price', 'total_area', 'rooms', 'city_centers_nearest']]
sns.pairplot(df_corr)

# %% [markdown]
# **Вывод**: Исходя из представленной таблицы корреляции и полученных графиков, ранее сделанные выводы по факторам, оказывающим наибольшее влияние на стоимость недвижимости необходимо скорректировать. Очевидно, что цена значительно зависит в первую очередь от площади помещения (и от количества комнат, которые, в свою очередь, имеют также прямую зависимость от площади). Влияние расстояния выражено в небольшой обратной зависимости - чем дальше квартира от центра, тем ниже ее стоимость, однако степень корреляции невысока.

# %% [markdown]
# ### Населенные пункты с наибольшим числом объявлений.

# %% [markdown]
# В данном разделе необходимо отобрать 10 населённых пунктов с наибольшим числом объявлений, рассчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
# применим метод сводных таблиц для определения числа объявлений и средней цены кв.метра
locality_name_price_mean = df.pivot_table(index='locality_name', values='price_metr', aggfunc=['count', 'mean'])

# %%
# переименуем столбцы
locality_name_price_mean.columns = ['count', 'mean']

# %%
# график по числу объявлений и средней цене для 15 первых объектов
locality_name_price_mean.sort_values(by='count', ascending=False).head(10).plot(x='mean', y='count', kind='scatter')
# Out:
# <AxesSubplot:xlabel='mean', ylabel='count'>

# %%
# отсортируем значения по убыванию и выведем первые 10 населенных пунктов
locality_name_price_mean.sort_values(by='count', ascending=False).head(10)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15721  114849.007812
# Мурино             590   86087.515625
# Кудрово            472   95324.929688
# Шушары             440   78677.367188
# Всеволожск         398   68654.476562
# Пушкин             369  103125.820312
# Колпино            338   75424.578125
# Парголово          327   90175.914062
# Гатчина            307   68746.148438
# Выборг             237   58141.910156

# %%
# Выделим населенные пункты с самой высокой средней стоимостью квадратного метра
locality_name_price_mean.sort_values(by='count', ascending=False).head(1)
# Out:
#                  count           mean
# locality_name
# Санкт-Петербург  15721  114849.007812

# %%
# населенный пункт с самой низкой средней стоимостью квадратного метра жилья
locality_name_price_mean.sort_values(by='count', ascending=False).tail(1)
# Out:
#                count          mean
# locality_name
# Плоское            1  20912.548828

# %% [markdown]
# **Выводы**: Определили 10 населенных пунктов, в которых было расположено самое большое количество объявлений. Самая высокая средняя стоимость квадратного метра оказалась в Санкт-Петербурге, а самая низкая - село Шум.

# %% [markdown]
# ### Зависимость цены от удаленности от центра в Санкт - Петербурге.

# %% [markdown]
# В данном разделе выделим в отдельный data frame квартир в Санкт-Петербурге, создадим столбец с расстоянием до центра в км (округленным до целого числа). Необходимо рассчитать среднюю цену для каждого км удаленности от центра, построить соответствующий график и определить границу центральной зоны.

# %%
# отдельный df с данными только для Санкт-Петербурга
df_sp = df.loc[df['locality_name'] == 'Санкт-Петербург']

# %%
# проверим данные по таблице
df_sp['locality_name'].value_counts()
# Out:
# Санкт-Петербург    15721
# Name: locality_name, dtype: int64

# %%
# добавление столбца с округленным до целого числа расстоянием до центра в км
df_sp['city_centers_nearest_km'] = round(df_sp['city_centers_nearest']/1000)

# %%
# рассмотрим распределение по количеству значений на каждом километре
df_sp['city_centers_nearest_km'].value_counts()
# Out:
# 12.0    1666
# 15.0    1568
# 13.0    1457
# 14.0    1279
# 16.0    1265
# 11.0    1178
# 5.0      920
# 17.0     883
# 10.0     719
# 4.0      688
# 6.0      618
# 8.0      597
# 9.0      593
# 7.0      420
# 3.0      350
# 2.0      310
# 18.0     261
# 22.0     202
# 1.0      192
# 19.0     157
# 21.0     117
# 23.0      85
# 26.0      53
# 20.0      49
# 0.0       27
# 25.0      26
# 24.0      26
# 28.0       7
# 29.0       6
# 27.0       2
# Name: city_centers_nearest_km, dtype: int64

# %%
# применим метод сводных таблиц 
df_sp_center = df_sp.pivot_table(index='city_centers_nearest_km', values='price_metr', aggfunc='mean')

# %%
df_sp_center.head()
# Out:
#                             price_metr
# city_centers_nearest_km
# 0.0                      245833.531250
# 1.0                      177005.406250
# 2.0                      157849.000000
# 3.0                      121387.453125
# 4.0                      133282.875000

# %%
# построим точечную диаграмму зависимости цены метра квадратного от удаленности от центра
df_sp_center.plot(style='o', figsize=(6, 7), grid=True, alpha = 0.9)
# Out:
# <AxesSubplot:xlabel='city_centers_nearest_km'>

# %% [markdown]
# **Вывод**: Средние значения распределены достаточно интересно, имеется две резких границы падения графика (т.е. средней стоимости квадратного метра квартиры) на расстоянии в 3 км от центра и 7 км от центра.Нам необходима именно первая граница разрыва в стоимости цен, поэтому будем считать центральным районом жилье, которое продают на расстоянии до 2-х км включительно (27 объектов недвижимости на расстоянии 0 км, 192 объекта на 1 км и 310 объектов на расстоянии в 2 км - всего 529 объектов недвижимости).
# В соответствии с условиями задания дополнительно расширим центр до расстояния 7 км.

# %% [markdown]
# ### Параметры сегмента квартир в центре Санкт - Петербурга.

# %% [markdown]
# В данном разделе необходимо повторить проведенное ранее исследование для сегмента квартир, находящихся на расстоянии до 7 км включительно от центра в Санкт-Петербурге и сравнить полученные результаты с общими значениями исследования по Санкт-Петербургу и региону.

# %%
# выделение из DF значений, относящихся к центру Санкт-Петербурга на расстоянии до 7 км от центра включительно.
df_sp_center = df_sp.loc[df_sp['city_centers_nearest_km'] <= 7]

# %%
# описание полученного df_sp_center
df_sp_center.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3525 entries, 3 to 23694
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   total_images               3525 non-null   int64
#  1   last_price                 3525 non-null   float64
#  2   total_area                 3525 non-null   float32
#  3   first_day_exposition       3525 non-null   datetime64[ns]
#  4   rooms                      3525 non-null   int64
#  5   ceiling_height             3524 non-null   float32
#  6   floors_total               3525 non-null   int64
#  7   living_area                3494 non-null   float32
#  8   floor                      3525 non-null   int64
#  9   is_apartment               3525 non-null   bool
#  10  studio                     3525 non-null   bool
#  11  open_plan                  3525 non-null   bool
#  12  kitchen_area               3490 non-null   float32
# ...

# %% [markdown]
# #### Изучение параметров квартир в центре Санкт-Петербурга.

# %% [markdown]
# ##### Площадь.

# %%
# описание данных столбца с общей площадью
df_sp_center['total_area'].describe()
# Out:
# count    3525.000000
# mean       93.168640
# std        59.473560
# min        12.000000
# 25%        57.000000
# 50%        78.699997
# 75%       110.000000
# max       631.200012
# Name: total_area, dtype: float64

# %%
# диаграмма рассеивания для столбца total_area
df_sp_center.boxplot(column='total_area')
plt.show()

# %%
# диаграмма рассеяния с исключением выбивающихся значений
df_sp_center.boxplot(column='total_area', showfliers = False)
plt.show()

# %%
# гистограмма распределения total_area
df_sp_center['total_area'].hist(bins=100, figsize=(20,5), color='skyblue')
plt.show()

# %%
# гистограмма распределения total_area с ограничением до 150 м2.
df_sp_center['total_area'].hist(bins=100, range=(10, 150), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Выводы**: Среднее значение увеличилось с 60 до 93 м2 общей площади квартиры. При этом основной разброс значений сосредоточен в диапазоне от 57 м2 до 110 м2, с медианным значением в 93 м2, тогда как ранее, для всех помещений, разброс составлял от 40 м2 до 66 м2 и медианным значением в 52 м2.

# %% [markdown]
# ##### Цена.

# %%
# описание данных столбца с ценой за квартиру
df_sp_center['last_price'].describe()
# Out:
# count    3525.000000
# mean       14.895529
# std        24.320912
# min         1.600000
# 25%         6.690000
# 50%         9.200000
# 75%        14.500000
# max       763.000000
# Name: last_price, dtype: float64

# %%
# диаграмма ящик для столбца last_price
df_sp_center.boxplot(column='last_price')
plt.show()

# %%
# диаграмма ящик для столбца last_price с исключением выбросов
df_sp_center.boxplot(column='last_price', showfliers = False)
plt.show()

# %%
# гистограмма распределения last_price
df_sp_center['last_price'].hist(bins=100, range=(0, 100), figsize=(20,5), color='skyblue')
plt.show()

# %%
# гистограмма распределения last_price
df_sp_center['last_price'].hist(bins=100, range=(0, 25), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Вывод**:
# В данном распределении основной диапазон цен заключен между 6 и 14.5 млн.рублей против 2 и 8 млн.руб для всего региона. Можно сделать вывод, что тип распределения остался без изменений, но непосредственно диапазон цен увеличился.

# %% [markdown]
# ##### Число комнат.

# %%
# описание данных столбца с количеством комнат
df_sp_center['rooms'].describe()
# Out:
# count    3525.000000
# mean        2.834326
# std         1.449808
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max        19.000000
# Name: rooms, dtype: float64

# %%
df_sp_center['rooms'].value_counts()
# Out:
# 3     1092
# 2     1033
# 1      519
# 4      489
# 5      217
# 6       83
# 7       54
# 0       17
# 8       10
# 9        3
# 10       2
# 11       2
# 14       1
# 16       1
# 15       1
# 19       1
# Name: rooms, dtype: int64

# %%
# диаграмма ящик для столбца rooms с исключением выбросов
df_sp_center.boxplot(column='rooms', showfliers = False)
plt.show()

# %%
# гистограмма распределения rooms с исключением количества комнат больше 6
df_sp_center['rooms'].hist(bins=10, range=(0, 10), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Вывод**: Основываясь на представленном распределении можно обратить внимание, что максимальное количество продаж приходится на 2 и 3 комнатные квартиры. Так же достаточно часто встречаются 4-х комнатные квартиры и 1-комнатные, и 5 и 6 и более комнатные квартиры.
# Отличается от данных по общему анализу, где основные продажи приходятся на 1 и 2-х комнатные квартиры.

# %% [markdown]
# ##### Высота потолков.

# %%
# описание данных столбца с высотой потолков
df_sp_center['ceiling_height'].describe()
# Out:
# count    3524.000000
# mean        2.970162
# std         0.736635
# min         2.400000
# 25%         2.650000
# 50%         2.880000
# 75%         3.170000
# max        32.000000
# Name: ceiling_height, dtype: float64

# %%
df_sp_center['ceiling_height'].value_counts()
# Out:
# 3.00     453
# 2.60     409
# 2.65     408
# 2.80     270
# 2.64     218
#         ...
# 5.60       1
# 2.67       1
# 27.00      1
# 4.90       1
# 3.82       1
# Name: ceiling_height, Length: 151, dtype: int64

# %%
# диаграмма рассеивания для столбца высота потолков  с исключением вбросов
df_sp_center.boxplot(column='ceiling_height', showfliers = False)
plt.show()

# %%
# гистограмма распределения значения высота потолков 
df_sp_center['ceiling_height'].hist(bins=100, range=(2.4, 5), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Вывод**: Наибольшее количество квартир в центре Санкт-Петербурга представлено с высотой потолков от 2,65 до 3,17
#  м. Прочие значения (максимальное 5,8 метров) встречаются крайне редко, практически в единичных случаях. По сравнению с общими показателями по высоте потолков, в центре представлен более широкий разброс со сравнимой частотой встречаемости.

# %% [markdown]
# #### Время продажи квартиры.

# %%
# рассмотрим описание, медиану и среднее для времени продажи квартир
df_sp_center['days_exposition'].describe()
# Out:
# count    2941.000000
# mean      247.676636
# std       273.540894
# min         3.000000
# 25%        60.000000
# 50%       142.000000
# 75%       346.000000
# max      1572.000000
# Name: days_exposition, dtype: float64

# %%
# диаграмма размаха
df_sp_center.boxplot(column='days_exposition')
plt.show()

# %%
# диаграмма размаха с исключением выбросов
df_sp_center.boxplot(column='days_exposition', showfliers = False)
plt.show()

# %%
# гистограмма распределения значения скорость продажи квартиры
df_sp_center['days_exposition'].hist(bins=100, figsize=(20,5), color='skyblue')
plt.show()

# %%
# гистограмма распределения значения скорость продажи квартиры
df_sp_center['days_exposition'].hist(bins=100, range=(0,200), figsize=(20,5), color='skyblue')
plt.show()

# %% [markdown]
# **Выводы**: Все продажи, совершенные в период от 3 до 60 дней можно считать "быстрой сделкой". Таких сделок менее 25% (на 60 дней приходится 1-й квантиль диаграммы размаха), за данный промежуток времени основной пик продаж приходится на 60 сутки после выставления объекта недвижимости на продажу. Самый пик продаж приходится на 85-90 сутки после выставления объекта недвижимости. После 500 суток наблюдается сильный спад количества совершенных сделок, поэтому срок выше 500 суток будет установлен как необычно долгий для сделки.

# %% [markdown]
# #### Зависимость цены от площади.

# %%
# построим точечную диаграмму зависимости цены от площади
df_sp_center.plot(x='total_area', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
xlim=(10, 200),
ylim=(0, 150))
# Out:
# <AxesSubplot:xlabel='total_area'>

# %% [markdown]
# **Выводы**: Зависисмость цены от площади выражена достаточно сильно, подробнее корреляция будет рассмотрена в отдельном блоке.

# %% [markdown]
# #### Зависимость цены от числа комнат.

# %%
# построим точечную диаграмму зависимости цены от числа комнат
df_sp_center.plot(x='rooms', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
xlim=(0,10),
ylim=(0, 100))
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# **Вывод**: Основываясь на представленной зависимости, можно обратить внимание, что существует достаточно сильная зависимость между стоимостью и увеличением числа комнат, особенно это касается диапазона от 1 до 4 комнатных квартир, тогда как для квартир с большим числом комнат данная тенденция не отслеживается. Подробнее корреляционная зависимость будет рассмотрена в отдельном блоке.

# %% [markdown]
# #### Зависимость цены от удаленности от центра.

# %%
# построим точечную диаграмму зависимости цены от удаленности от центра
df_sp_center.plot(x='city_centers_nearest', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 100))
# Out:
# <AxesSubplot:xlabel='city_centers_nearest'>

# %% [markdown]
# **Выводы**: Судя по полученным данным, зависимость цены от удаленности от центра не выражена.

# %% [markdown]
# #### Зависимость цены от этажа.

# %%
# рассортируем значения по этажам для объектов недвижимости в центре и обозначим медианное значение.
floor_sorted_sp_center=df_sp_center.groupby('floor_category')['last_price'].median()

# %%
# построим гистограмму зависимости цены от категории этажа
# используем метод по заданию в качестве оси х индексов нашей таблицы, а y -медианное значение последней цены продажи
floor_sorted_sp_center.plot(x=floor_sorted_sp_center.index, 
y=floor_sorted_sp_center.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# **Вывод**: Наблюдается схожая тенденция, наименьшая стоимость принадлежит первому этажу, тогда как для остальных этажей разницы практически нет.

# %% [markdown]
# #### Зависимость цены от дня недели размещения.

# %%
# группировка по дням недели, определение медианы
weekdays_sorted_sp_center=df_sp_center.groupby('week_day_exposition')['last_price'].median()

# %%
# гистограмма распределения медианных значений
weekdays_sorted_sp_center.plot(x=weekdays_sorted_sp_center.index, 
y=weekdays_sorted_sp_center.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='week_day_exposition'>

# %%
# построим точечную диаграмму зависимости цены от дня недели
df_sp_center.plot(x='week_day_exposition', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 200))
# Out:
# <AxesSubplot:xlabel='week_day_exposition'>

# %% [markdown]
# **Вывод**: Не наблюдается существенная зависимость стоимости недвижимости в зависимости от дня недели.

# %% [markdown]
# #### Зависимость цены от месяца размещения.

# %%
# группировка по месяцам, определение медианы
month_sorted_sp_center=df_sp_center.groupby('month_exposition')['last_price'].median()

# %%
# гистограмма распределения медианных значений
month_sorted_sp_center.plot(x=month_sorted_sp_center.index, 
y=month_sorted_sp_center.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='month_exposition'>

# %%
# построим точечную диаграмму зависимости цены от месяца
df_sp_center.plot(x='month_exposition', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 200))
# Out:
# <AxesSubplot:xlabel='month_exposition'>

# %% [markdown]
# **Выводы**: Значительная зависимость цены продажи объекта недвижимости от месяца, в котором была выставлена недвижимость на продажу не выявлена.

# %% [markdown]
# #### Зависимость цены от года размещения.

# %%
# группировка по годам, определение медианы
year_sorted_sp_center=df_sp_center.groupby('year_exposition')['last_price'].median()

# %%
# гистограмма распределения медианных значений
year_sorted_sp_center.plot(x=year_sorted_sp_center.index, 
y=year_sorted_sp_center.values,
kind='bar',
figsize=(6, 7),
grid=True,
alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='year_exposition'>

# %%
# построим точечную диаграмму зависимости цены от месяца
df_sp_center.plot(x='year_exposition', 
y='last_price', 
style='o', 
figsize=(6, 7),
grid=True,
alpha = 0.3,
ylim=(0, 200))
# Out:
# <AxesSubplot:xlabel='year_exposition'>

# %% [markdown]
# **Выводы**: Зависимость от года выставления на продажу не выявлена.

# %% [markdown]
# #### Определение корреляционной зависимости между параметрами цена, количество комнат, общая площадь и расстояние до центра.

# %%
df_sp_center[['last_price', 'total_area', 'rooms', 'city_centers_nearest']].corr()
# Out:
#                       last_price  total_area     rooms  city_centers_nearest
# last_price              1.000000    0.613480  0.314874             -0.042186
# total_area              0.613480    1.000000  0.730397             -0.093031
# rooms                   0.314874    0.730397  1.000000             -0.170847
# city_centers_nearest   -0.042186   -0.093031 -0.170847              1.000000

# %%
# отобразим полученные зависимости графически
df_corr_sp_center=df_sp_center.loc[:, ['last_price', 'total_area', 'rooms', 'city_centers_nearest']]
sns.pairplot(df_corr)

# %% [markdown]
# **Выводы**: Цена, площадь и количество комнат объекта недвижимости практически не зависят от расстояния до центра. Цена имеет высокую прямую зависимость от площади и небольшую пряму зависимость от количества комнат (которые свзяны между собой достаточно высокой прямой зависимостью).

# %% [markdown]
# #### Выводы по исследованию для сегмента центр Санкт - Петербурга.

# %% [markdown]
# Сравнивая исследования рынка центрального сегмента Санкт-Петербурга, ограниченного расстоянием в 7 км включительно, можно сделать вывод о том, что данные объекты имеют более высокую медианную площадь, ожидаемо более высокий диапазон цен, более популярны 2-х и 3-х комнатные квартиры, более широкий разброс высот потолков (скорее всего за счет исторической застройки и нестандартных решений).
#
# Время продажи квартир в условиях как быстрой сделки так и необычайно долгой больше, чем для остальных значений по Санкт-Петербургу и области, как и медианное значение времени продажи.
#
# Зависимость цены от площади как для df, так и для центрального сегмента выражена достаточно сильно и имеет прямую зависимость, т.е. чем выше площадь квартиры, тем выше ее конечная стоимость.
#
# Цена напрямую зависит от числа комнат, при этом для центрального сегмента такая зависимость сохряняется до 4-х комнатных квартир, а для общего df до 5-комнатных квартир. Для квартир с количеством комнат выше указанного, тенденция не сохраняется.
#
# Для общего df имеет неярко выраженную обратную пропорциональность расстоянию от центра, тогда как для непосредственно центрального сегмента Санкт-Петербурга такая зависимость практически отсутствует.
#
# Обнаруженная зависимость цены от категории этажа достаточно интересна: первый этаж вне зависимости от расположения квартиры имеет самую низкую стоимость, тогда как для последнего и других этажей стоимость практически одинакова.
#
# Не наблюдается определенная зависимость цены продажи квартиры от дня недели размещения, от месяца размещения. Для центрального сектора Санкт-Петербурга зависимость от года размещения также не наблюдается.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Целью исследования являлась **оценка основных параметров недвижимости и степень их связи с рыночной стоимостью недвижиимости.**
#
# В ходе выполнения работы была проведена предварительная подготовка данных, имеющиеся пробелы в значениях были заполнены в максимально возможном объеме для обеспечения точности получаемых сведений.
#
# Для дальнейших расчетов в исходный df были добавлены следующие столбцы:
# * price_metr - цена квадратного метра (отношение цены продажи к общей площади)
# * week_day_exposition - день недели размещения объявления о продаже объекта
# * month_exposition - месяц размещения объявления о продаже объекта
# * year_exposition - год размещения объявления о продаже объекта
# * floor_category - категория этажа объекта недвижимости (первый, последний, другое)
# * living_total_correlation - соотношение жилой площади к общей
# * kitchen_total_correlation - соотношение площади кухни к общей площади.
#
# Дальнейшее исследование было разделено на два крупных блока: одна часть исследования охватывала весь представленный df, а в рамках второй части исследования была выделена центральная область Санкт-Петербурга и именно данная центральная область была проанализированна отдельно. Для выделения центральной области Санкт-Петербурга была рассмотрена зависимость медианной цены на каждом километре от центра и выявлено, что к центральному сегменту может быть отнесено жилье, которое продают на расстоянии до 7 км включительно.
#
# Рассмотрим каждую часть исследования и полученные по ним выводы более подробно.
#
# При изучении**параметров квартир**  можно выделить следующие особенности:
# * площадь квартир в центральной части Санкт-Петербурга выше, чем в целом по региону, так разброс значений для центральной части составляет от 57 м2 до 110 м2, с медианным значением в 93 м2, а для Ленинградской области в целом разброс составлял от 40 м2 до 66 м2 с медианным значением в 52 м2.
# * наиболее часто встречаемая цена и ее разброс также занимают более высокие значения в центральной части Санкт-Петербурга.
# * в центральной части чаще выставлены на продажу 2-х и 3-х комнатные квартиры, достаточно большой объем приходится на 4-х комнатные. Тогда как по региону в целом максимальное количество объявлений представлено для 1 и 2-х комнатных квартир, реже для 3-х комнатных квартир. В обоих случаях, квартир свыше 4-х комнат представлено достаточно небольшое количество.
# * высота потолков и их разброс являются достаточно интересным параметром из-за особенностей строительной архитектуры Санкт-Петербурга. Однако, значительного перевеса данных в пользу "высоких" потолков, какими славится застройка в Санкт-Петербурге не было выявлено, в том числе и для центрального сегмента.
#
# **Время продажи** квартиры для центральной части и региона в целом отличаются:  для центральной части Санкт-Петербурга сделка считается быстрой, если совершена до 65 дней, тогда как для области такой срок составляет до 45 дней. Пик продаж в центре приходится на 85-90 сутки, для регионов явных пиков продаж не выявлено. Необычно долгой сделка становится на 400 сутки для центра и после 500 суток для региона.
#
# **Зависимость цены от площади недвижимости** выявлена, является прямой и достаточной сильной.
#
# **Число комнат**. В регионе для квартир с количеством комнат менее 5 цена прямо пропорционально возрастает к числу комнат, тогда как для недвижимости с большим числом комнат такой зависимости нет. Данная тенденция прослеживается и для центра Санкт-Петербурга, только для квартир до 4-х комнат.
#
# **Удаленность от центра** обратно пропорциональна стоимости недвижимости для Санкт-Птеребурга и окрестностей, однако для центральной части города данное утверждение не подтвердилось, зависимость практически отсутствует (имеется ввиду сектор города в районе 7 км от центра).
#
# **День недели, месяц** размещения объявления о продаже недвижимости не оказывает влияния на стоимость недвижимости, однако год в целом имеет более ярко выраженную зависимость, особенно для квартир из общего df. Это объясняется инфляцией и общим колебанием цен на рынке всей недвижимости.
#
# Дополнительно были выявлены 10 населенных пунктов с наибольшим числом объявлений, к ним относятся: Санкт-Петербург, поселок Мурино, поселок Шушары, Всеволожск, Пушкин, Колпино, поселок Парголово, Гатчина, деревня Кудрово и Выборг. Самая высокая средняя стоимость квадратного метра оказалась в Санкт-Петербурге, а самая низкая - село Шум.
